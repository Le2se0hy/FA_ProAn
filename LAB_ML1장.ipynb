# %% [markdown]
# <a href="https://colab.research.google.com/github/Le2se0hy/FA_ProAn/blob/main/LAB_ML1%EC%9E%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 핸즈온 머신러닝_1장

# %% [markdown]
# 0108(목) - p.27 ~ p.43 (1.41)
#
# 0109(금) - p.44(1.42) ~ p.62(1.6.1)
#
# 0112(월) - p.62(1.6.1) ~ p.67(1장 완료)

# %% [markdown]
# ---
# # 1.1  머신러닝이란?
#
# " 머신러닝은 데이터에서 학습하도록 컴퓨터를 프로그래밍하는 과학 "
# - 공학적 정의 : 어떤 작업 T에 대한 컴퓨터 프로그램의 성능을 P를 측정했을때 경험 E로 인해 성능이 향상됐다면, 이 컴퓨터 프로그램은 작업 T와 성능 측정 P에 대해 경험 E로 학습하는 것이다.

# %% [markdown]
# 예) 스팸필터
# - 작업T = 새로운 메일이 스팸인지 구분하는 것
# - 경헙E = 훈련 데이터
# - 성능측정P = 직접 정의해야함. 예를 들면 정확히 분류된 메일의 비율이라면 P는 정확도

# %% [markdown]
# Keywords
# - 훈련 세트 : 시스템이 학습하는 데 사용하는 샘플
# - 훈련 사례 or 샘플 : 각각의 훈련 데이터
# - 모델 : 머신러닝 시스템에서 학습하고 예측을 만드는 부분 (eg. neural network, random forest)

# %% [markdown]
# ---
# # 1.2 왜 머신러닝을 사용하나요?

# %% [markdown]
# 위에서 말한 주류가 된 첫번째 머신러닝 애플리케이션인 스팸필터를 예를 들어 설명하자면
#
# 전통적인 프로그래밍 기법
# 1. 문제연구 - 스팸에 어떤 단어가 주로 나타나는지 살펴보며 경향 파악
# 2. 규칙작성 - 발견한 패턴과 경향을 감지하는 알고리즘을 작성하여 스팸인 패턴을 발견했을때 그 메일을 스팸으로 분류하게함
# 3. 평가 - 프로그램을 테스트하고 성능을 계속 평가
# 4. 오류 분석 / 론칭 - 충분한 성능이 나올때까지 오류분석 후 1단계와 2단게를 반복하고 충분한 성능이 나온다면 론칭
#
# 반면 머신러닝 기법에 기반을 둔 스팸 필터는 일반 메일에 비해 스팸에 자주 나타나는 패턴을 "**감지**"하여 어떤 단어와 구절이 스팸 메일을 판단하는 데 좋은 기준인지 "**자동으로 학습**"함.
#
# 만약 스팸메일 발송자가 '4U'를 포함한 모든 메일이 차단된다는 것을 알고 'For U'를 사용하기 시작한다면
# - 전통적인 프로그래밍 : 'For U'를 포함한 메일도 스팸으로 구분하기 위한 수정이 필요함
# - 머신러닝 : 사용자가 스팸으로 지정한 메일에 'For U'가 자주 나타나는 것을 **자동**으로 인식하기에 별도의 작업을 하지 않아도 이 단어를 스팸으로 분류.

# %% [markdown]
# 전통적인 방식으론 너무 복잡하거나 알려진 알고리즘이 없는 경우에도 머신러닝을 사용한다.

# %% [markdown]
# 또한 머신러닝 알고리즘이 학습하는 것을 알 수 있다. 모델이 예측한 결과를 통해 예상치 못한 상관관계나 새로운 추세가 발견되기도 해서 해당 문제를 더 잘 이해하도록 도와준다.
# 이처럼 대용량의 데이터를 분석하여 숨겨진 패턴을 발견하는 것을 **데이터 마이닝**이라고 함.

# %% [markdown]
# 요컨대, 머신러닝은
# - 기존의 전통적인 프로그래밍으로는 많은 수동적인 조정과 규칙이 필요한 문제
# - 기존의 방식으로는 해결 방법이 없는 복잡한 문제
# - 유동적인 환경
# - 복잡한 문제와 대량의 데이터에서 인사이트를 얻기
#
# 와 같은 분야에 뛰어나기에 사용한다.

# %% [markdown]
# ---
# # 1.3 애플리케이션 사례
#
# - 주로 CNN(합성곱 신경망). NLP(자연어 처리), RNN(순환 신경망), NLU(자연어 이해), .... 많은 예시들과 사용한 기술이 적혀있음
# - 추후에 각자 이해를 해보도록합시다....(ㅜㅜ)

# %% [markdown]
# ---
# # 1.4 머신러닝 시스템의 종류
#
# - 훈련 지도 방식 (지도, 비지도, 준지도, 자기지도, 강화학습)
# - 실시간으로 점진적인 학습을 하는지의 여부 (온라인 학습, 배치 학습)
# - 데이터 포인트와 새 데이터 포인트를 비교 / 훈련 데이터셋에서 패턴을 발견하여 예측 모델을 만드는지 (사례 기반 학습, 모델 기반 학습)

# %% [markdown]
# ## 1.4.1 훈련 지도 방식
#
# 머신러닝 시스템을 학습하는 동안의 **지도 형태**나 **정보량**에 따라 분류

# %% [markdown]
# ### [지도 학습]
#
# 지도학습에서는 알고리즙에 주입하는 훈련 데이터에 **레이블label**이라는 원하는 답이 포함됨
#
# - 분류
# - 회귀 : 특성(예측 변수 or 속성)을 사용하여 타깃 수치를 예측 (eg. 로지스틱 회귀 : 클래스에 속할 확률 출력)

# %% [markdown]
# ### [비지도 학습]
#
# 비지도 학습은 훈련 데이터에 레이블이 없고 시스템이 아무 도움 없이 학습함
# - 계층 군집 : 각 그룹을 더 작은 그룹으로 세분화하는 알고리즘
# - 시각화 : 레이블이 없는 대규모의 고차원 데이터를 넣으면 도식화가 가능한 2D, 3D 표현을 만드는 알고리즘
# - 차원 축소 : 상관관계가 있는 여러 특성을 하나로 합쳐 데이터를 간소화 시키는 알고리즘
# - 이상치 탐지 : 학습 알고리즘에 주입하기 전 데이터셋에서 이상한 값을 자동으로 제거하는 알고리즘. 훈련하는 동안 대부분은 정상 샘플을 만나 인식하도록 훈련 후 새로운 샘플을 보고 정상 데이터인지 이상치인지 판단
# - 특이치 탐지 : 훈련 세트에 있는 모든 샘플과 달라 보이는 새로운 샘플을 탐지. 알고리즘으로 감지하고 싶은 샘플을 모두 제거한 매우 깨끗한 훈련세트가 필요하다..
# -> 이는 훈련세트에 이상치가 섞여있으면 모두 정상으로 인지하기에 이상치를 탐지하지 못한다. 그러므로 이상치가 없는 훈련세트가 필요하다는 뜻이다.
# - 연관 규칙 학습 : 대량의 데이터에서 특성 간의 흥미로운 관계를 찾는 알고리즘

# %% [markdown]
# ### [준지도 학습]
#
# 데이터에 레이블을 다는 것은 일반적으로 시간과 비용이 많이 들기 때문에 레이블이 없는 샘플이 많고 레이블된 샘플은 적은 경우가 많다. 일부만 레이블된 데이터를 다룸.
#
# 대부분의 준지도 학습 알고리즘은 지도 학습과 비지도 학습의 조합으로 이루어짐. 예를 들어 군집 알고리즘을 사용해 비슷한 샘플을 한 그룹으로 모으고 그 다음에 레이블이 없는 샘플에 클러스터에서 가장 많이 등장하는 레이블을 할당함. 전체 데이터셋에 레이블이 부여되고 나면 지도 학습 알고리즘을 사용할 수 있음.

# %% [markdown]
# ### [자기 지도 학습]
#
# 레이블이 없는 데이터셋에서 레이블이 완전히 부여된 데이터셋을 생성함
#
# 자기 지도 학습의 예 : 레이블이 없는 이미지로 구성된 대량의 데이터셋이 있다면 각 이미지의 일부분을 랜덤하게 마스킹하고 모델이 원본 이미지를 복원하도록 훈련하고 훈련하는 동안 마스킹된 이미지는 모델의 입력으로 사용되며 원본 이미지는 레이블로 사용됨.

# %% [markdown]
# ####[전이 학습]
# 이란 한 작업에서 다른 작업으로 지식을 전달하는 것이다.
#
# 종종 자기 지도 학습을 사용해 훈련된 모델이 최종 목적이 아닌 경우가 많다. 조금 다르지만 실제 관심 대상인 작업을 위해 모델을 수정하거나 미세 튜닝함.
# -> 자기 지도 학습으로 이미지 복원 모델을 훈련 후 수정하여 반려동물 분류 모델로 만듬.

# %% [markdown]
# ### [강화 학습]
#
# 학습하는 시스템을 **에이전트**라고 부르는데 환경을 관찰하여 행동을 실행하고 그 결과로 보상 또는 부정적인 보상인 경우엔 벌점을 받음. 시간이 지나며  가장 큰 보상을 얻기 위해 **정책**이라 부르는 최상의 전략을 스스로 학습하는 것이 강화학습이다. 정책은 주어진 상황에서 에이전트가 어떤 행동을 해야하는지 정의함.
#
# - 알파고 : 2017년 바둑에서 당시 세계 랭킹 1위인 커제선수를 이긴 프로그램으로 강화학습의 좋은 예.
# 수백만 개의 게임을 분석 후 승리 전략을 학습하고 자기 자신과의 많은 게임을 하였음. 알파고가 세계 챔피언과 게임할 때는 학습 기능을 끄고 과거에 학습했던 전략을 사용함(오프라인 학습)

# %% [markdown]
# ## 1.4.2 배치 학습과 온라인 학습
#
# 입력 데이터의 스트림으로부터 **점진적으로** **학습**할 수 있는지 여부로 분류함
#
# (스트림이라는 단어가 명확히 이해되지 않아 찾아본 결과 : 스트림이란 데이터가 시간에 따라 순차적으로, 즉 연속적으로 들어오는 것을 의미한다.
#
# 위의 기준을 풀이하자면 데이터가 시간에 순차적으로 들어올 때,
# 그걸 하나하나 받아서 모델을 계속 업데이트할 수 있는지로 배치 학습과 온라인 학습이 나눠지는 것이다!!)

# %% [markdown]
# ### [배치 학습]
#
# 시스템이 점진적으로 학습할 수 없고 가용한 데이터를 모두 사용해 훈련해야함.
#
# - 일반적으로 시간과 자원을 많이 소모하므로 오프라인에서 수행
# - 시스템을 우선적으로 훈련시킨 다음 제품 시스템에 적용하면 더 이상의 학습 없이 실행되며 **학습한** **것을** **단지** **적용**만 함
# (= 오프라인 학습)
# - 모델 부패 / 데이터드리프트 : 세상은 진화하는데 모델은 바뀌지않으면 모델의 성능은 시간이 지남에 따라 천천히 감소
# - 모델 부패의 해결방법 : 모델을 정기적으로 재훈련
#
# 배치 학습 시스템이 새로운 데이터에 대해 학습하려면 전체 데이터를 사용하여 시스템의 새로운 버전을 처음부터 다시 훈련 후 새 모델로 교체 해야함.
#
#
# 머신러닝 시스템에서 이 모든 과정이 자동화가 되고 새 버전이 필요한 만큼 자주 훈련시키면 되지만..
# - 훈련하는데 오랜 시간이 걸린다.
# - 시스템이 빠르게 변하는 데이터에 적응해야 한다.
# - 많은 컴퓨팅 자원이 필요하다. 즉, 큰 비용이 발생한다.
# - 데이터 양이 방대하다.
# - 자원이 제한된 시스템(eg. 스마트 폰, 화성 탐사 로버)이 스스로 학습해야 할 때 몇 시간 씩 학습을 위해 많은 자원을 사용하여 심각한 문제를 일으킨다.
#
# 와 같은 경우에는 점진적으로 학습할 수 있는 알고리즘을 사용해야함 (= 온라인 학습)

# %% [markdown]
# ### [온라인 학습 (= 점진적 학습)]
#
# 데이터를 순차적으로 한 개씩 또는 미니배치라 부르는 작은 묶임 단위로 주입하여 시스템을 훈련시킴
#
# (배치 학습에 비해) 매 학습 단계가 빠르고 비용이 적게 들어 데이터가 도착하는 ~~실시간으로 즉시~~ 학습 할 수 있음
#
# ###### *"실시간으로 즉시"라는 말은 공부해보니 잘못된 표현이다. 온라인 학습 및 점진적 학습은 데이터가 순차적으로 와도 학습 가능하다는 뜻이지 실시간을 만족하지는 않는다. 데이터 도착 후 지연이 있을 수도 있다. 주의 합시다.*
#
# - 온라인 학습 알고리즘을 사용하여 컴퓨터 한 대의 메인 메모리에 들어갈 수 없는 큰 데이터셋에서 모델을 훈련할 수 있음(외부 메모리 학습)
# - 대량의 데이터를 처리할 때 알고리즘이 데이터 일부를 읽어들이고 훈련 단계를 수행하고 전체 데이터가 모두 적용될 때까지 반복함
# - **학습률** : 변화하는 데이터에 얼마나 빠르게 적응할 것인지를 확인하는 파라미터
# - 학습률이 높은 경우 : 시스템이 데이터에 빠르게 적응, 예전 데이터를 금방 잊어버림
# - 학습률이 낮은 경우 : 시스템의 관성이 더 커져서 느리게 학습됨, 새로운 데이터에 있는 잡음이나 대표성 없는 데이터 포인트에 덜 민감해짐.
#
# <장점>
# - 극도로 빠른 변화에 적응해야하는 시스템에 적합
# - 컴퓨팅 자원이 제한된 경우에 적합
#
# <단점>
# - 시스템에 나쁜 데이터가 주입되었을 때 시스템이 성능이 감소
# - 데이터 품질이나 학습률에 따라 성능이 빠르게 감소할 수 있음
# -> 시스템을 면밀히 모니터링하고 성능이 감소가 감지되면 즉각 학습을 중지시켜야함 / 입력 데이터를 모니터링해서 비정상 데이터를 이상치 탐지 알고리즘과 같은 것을 사용하여 잡아내야함

# %% [markdown]
# ## 1.4.3 사례 기반 학습과 모델 기반 학습
#
# 어떻게 **일반화**되는가에 따라 머신러닝 시스템을 분류함
#
# 주어진 훈련 데이터로 학습하고 본 적 없는 새로운 데이터에서 좋은 예측을 만들어야(일반화되어야)함

# %% [markdown]
# ### [사례 기반 학습]
#
# 시스템이 훈련 샘플을 기억함으로써 학습하고 **유사도 측정**을 사용해 새로운 데이터와 학습한 샘플을 비교하는 식으로 일반화함
#
# 예를 들어 특성1이 X고 특성2가 Y인 그래프에서 삼각형과 사각형의 형태를 띈 훈련 샘플들이 분포되어 있다. 거기에 직각삼각형의 형태를 띈 새로운 샘플을 넣었을때 특성1과 특성2에 따라 그래프에 위치하게 될 것이고 그 새로운 샘플의 근처(즉, 가장 비슷한 샘플) 중 다수가 삼각형이면 새로운 샘플은 삼각형 클래스로 분류될 것이다.
#
# ~~그림 첨부를 했더니,,오류가 나 저장되지 않은 부분이 날라가 그림 대신 글로 표현한다~~

# %% [markdown]
# ### [모델 기반 학습]
#
# 샘플들의 모델을 만들어 **예측**에 사용하여 일반화함

# %% [markdown]
# ### [모델 기반 학습의 예 : 돈이 사람을 행복하게 만드는가?에 대한 예측 모델]
#
# - 사용 데이터 : 더 나은 삶의 지표(OECD), 1인당 GDP 데이터(세계 은행 통계)
#
# 두 데이터 테이블을 합치고 1인당 GDP로 정렬하고 그래프로 나타내면 데이터가 흩어져 있지만(즉, 어느 정도의 무작위성이 있지만) 삶의 만족도는 1인당 GDP가 증가할수록 거의 선형으로 같이 상승함
#
# - 1.모델 선택 : 1인당 GDP의 선형 함수로 삶의 만족도를 모델링 -> 1인당 GDP라는 특성 하나를 가진 삶의 만족도에 대한 선형 모델을 선택함
# - *$삶의 만족도 = θ_0 + θ_1 * 1인당 GDP$*
# - 위의 선형 모델에서 $θ_0$과 $θ_1$을 가짐. 이 파라미터들을 조정하여 선형 함수를 표현하는 모델을 얻을 수 있음.
#
#
# - 모델을 사용하기 전 이 두 파라미터의 값을 정의해야함
# - 모델이 최상의 성능을 내도록 하는 값을 어떻게 구함? -> 측정 지표를 정해야함
# - 효용 함수utility function / 적합도 함수 : 모델이 얼마나 좋은지 측정하는 함수
# - **비용 함수**cost function : 모델이 얼마나 나쁜지 측정하는 함수 -> 보통 선형 회귀에서는 선형 모델의 예측과 훈련 데이터 사이의 거리를 재는 비용함수를 사용 (해당 거리를 좁히는 것을 목표로 함)
# - 선형 회귀 알고리즘을 사용하여 알고리즘에 훈련 데이터를 공급하면 데이터에 가장 잘 맞는 선형 모델의 파라미터를 찾음(= 훈련시킴)

# %%
import matplotlib.pyplot as plt  # matplotlib : 데이터를 시각화하거나 그래프를 그릴때 사용하는 라이브러리
                                 # pyplot : matplotlib의 하위모듈이며 플로팅 인터페이스를 뜻함. 그래프 그리는 간단한 도구
import pandas as pd  # pandas : 데이터를 처리하고 분석하는 라이브러
from sklearn.linear_model import LinearRegression # LinearRegression : scikit-learn의 선형 회귀 모델 클래스

# 데이터를 다운로드하고 준비합니다.
data_root = "https://github.com/..."  # 데이터가 있는 기본 URL처럼 쓰려는 문자열
lifesat = pd.read_csv(data_root + "lifesat/lifesat.csv")  # data_root에 있는 url을 타고 들어가서 lifesat/lifesat.csv라는 데이터를 불러와
                                                          # 넣는다. () 속은 읽어올 csv의 경로를 지정

X = lifesat[["GDP per capita (USD)"]].values  # 대괄호 속 내용만 뽑아서 변수에 넣음. [[]] : 결과를 DataFrame(2차원) 으로 유지하려고
y = lifesat[["Life satisfaction"]].values  # .values : pandas DataFrame을 NumPy 배열로 변환
                                           # 2차원으로 유지 시 (샘플,1)과 같은 형태로 이루어짐

# 데이터를 그래프로 나타냅니다.
lifesat.plot(kind='scatter', grid=True, x="GDP per capita (USD)", y="Life satisfaction")  # scatter : 산점도, grid=True : 격자표시
                                                                                          # X축과 Y축에 각각 사용할 열이름 (위와 다르면 에)
plt.axis([23_500, 62_500, 4, 9])  # 축 범위를 고정, plt.axis([xmin, xmax, ymin, ymax])로 여기선 x: 23500 ~ 62500, y: 4 ~ 9
plt.show()  # 그래프 출

# 선형 모델을 선택합니다.
model = LinearRegeression()  # 빈 선형 회귀 모델 생성

# 모델을 훈련합니다.
model.fit(X, y)  # 데이터로 모델 파라미터(기울기/절편)를 학습함. 기울기:a (해당 모델에선 θ_1), 절편:b (θ_0)로 선형 모델에선 y=aX+b 형태

# 키프로스 샘플에 대한 예측을 만듭니다.
X_new = [[37_655.2]]  # 2020년 키프로스의 1인당 GDP
print(model.predict(X_new))  # 출력 : [[6.30165767]]

# %% [markdown]
# *위의 모델에 사례 기반의 학습 알고리즘을 사용한다면 1인당 GDP가 키프로스와 가장 가까운 이스라엘을 찾고 데이터에서 이스라엘의 만족도가 7.2이므로 키프로스의 삶의 만족도를 7.2로 예측함. 그 다움으로 가까운 두 나라를 고려하면 삶의 만족도가 5.9인 리투아니아와 슬로베니아가 있음. 이 세 값의 평균을 구하면 모델 기반의 예측과 비슷한 6.33이 됨. = k-최근접 이웃 회귀 (위와 같은 예시에선 k=3)*
#
# *위 코드에서 선형회귀 -> k-최근접 이웃 회귀로 바꾸려면*
#
#
#
# ```
# from sklearn.linear_model import LinearRegression
# model = LinearRegression()
# 을
# from sklearn.neighbors import KNeighborsRegressor
# model = KNeighborsRegresser(n_neighbors=3)
# ```
#
# *로 수정해야함*

# %% [markdown]
# ### [요약]
#
# 1. 데이터를 분석한다
# 2. 모델을 선택한다
# 3. 훈련 데이터로 모델을 훈련시킨다 -> 학습 알고리즘이 비용 함수를 최소화하는 모델 파라미터를 찾는다
# 4. 잘 일반화되기를 기대하면서 새로운 데이터에 모델을 적용해 예측을 만든다(=추론)

# %% [markdown]
# ---
# ## 1.5 머신러닝의 주요 도전 과제
#
# 모델을 선택해서 어떤 데이터에 훈련시키는 것이 주요 작업 이기에 문제가 되는 것은 '나쁜 모델'과 '나쁜 데이터'임

# %% [markdown]
# ### 1.5.1 나쁜 데이터 : 충분하지 않은 양의 훈련 데이터

# %% [markdown]
# ### 1.5.2 나쁜 데이터 : 대표성 없는 훈련 데이터
#
# 일반화가 잘되려면 훈련 데이터가 일반화하고 싶은 새로운 사례를 잘 대표하는 것이 중요함.
# - 샘플링 잡음 : 샘플이 작으면 우연에 의한 대표성 없는 데이터가 생김
# - 샘플링 편향 : 큰 샘플을 사용하지만 표본 추출 방법이 잘못되어 대표성을 띠지 못할 수 있음

# %% [markdown]
# ### 1.5.3 나쁜 데이터 : 낮은 품질의 데이터
#
# 훈련 데이터에 잡음이 가득하다면 머신러닝이 내재된 패턴을 찾기 어려움 -> 데이터 정제의 중요성
#
# 훈련 데이터 정제가 필요한 경우 :
# - 일부 샘플이 이상치라는게 명확 -> 해당 샘플을 무시 또는 수정
# - 일부 샘플에 특성 몇 개가 빠짐 -> 해당 샘플을 무시할지, 빠진 값을 평균값 등으로 채울지, 등등...

# %% [markdown]
# ### 1.5.4 나쁜 데이터 : 관련없는 특성
# 특성 공학과  같은 과정으로 훈련에 사용할 좋은 특성들을 찾아서 해결해야함
#
# 특성공학:
# - 특성 선택 : 가지고 있는 특성 중에서 훈련에 가장 유용한 특성을 선택
# - 특성 추출 : 특성을 결합하여 더 유용한 특성을 만듬 (차원 축소 알고리즘)
# - 데이터 수집 : 새로운 데이터를 수집해 새 특성을 만듬

# %% [markdown]
# ### 1.5.5 나쁜 모델 : 훈련 데이터 과대적합overfitting
#
# 훈련 데이터의 양과 잡음에 비해 모델이 너무 복잡할 때 발생함
# - 파라미터 수가 적은 모델을 선택하거나
# - 훈련 데이터의 특성을 줄이거나
# - 모델의 제약을 가하여 단순화 시키거나
# - 훈련 데이터를 더 모으거나
# - 잡음을 줄여
#
# 해결함
#
# - **규제** : 모델을 단순하게 하고 과대적합의 위험을 줄이기 위해 모델에 제약을 가하는 것
# - 자유도 : 모델이 데이터를 맞추기 위해 얼마나 마음대로 움직일 수 있는지를 나타내는 수치. 크고 많을수록 과대적합의 가능성이 높음. 규제로 자유도를 낮음
# - 하이퍼파라미터 : 적용할 규제의 양으로 학습 알고리즘의 파라미터. 학습 알고리즘으로부터 영향을 받지 않고, 훈련 전에 미리 지정되며, 훈련하는 동안에는 상수로 남아 있음. 적절한 값을 정해야함

# %% [markdown]
# ### 1.5.6 나쁜 모델 : 훈련 데이터 과소적합underfitting
#
# 모델이 너무 단순해서 데이터의 내재된 구조를 학습하지 못할 때 일어남
#
# 해결방법 :
# - 모델 파라미터가 더 많은 강력한 모델 선택
# - 학습 알고리즘에 더 좋은 특성을 제공 ( 특성공학 )
# - 모델의 제약을 줄임 ( 규제 하이퍼파라미터를 감소 )

# %% [markdown]
# ---
# ## 1.6 테스트와 검증
#
# 모델이 새로운 샘플에 얼마나 잘 일반화될지 알 수 있는 방법은 새로운 플에 적용해보는 것임
#
# 훈련 데이터를 훈련 세트와 테스트 세트로 나누고 훈련 후 테스트를 했을때 새로운 샘플에 대한 오차 비율을 **일반화 오차**라고 함. 테스트 세트에서 모델을 평가하며 이 오차에 대한 추정값이 나오는데 이 값은 새로운 샘플에 모델이 얼마나 잘 작동할지 알려줌.
#
# 훈련 오차가 작지만 일반화 오차가 큼 = 모델이 과대적합 됨

# %% [markdown]
# ### 1.6.1 하이퍼파라미터 튜닝과 모델 선택
#
# 모델을 평가할 때 테스트 세트를 사용하여 얼마나 잘 일반화되는지 비교하면 됨
#
# 과대적합을 피하기 위해 규제를 적용할 때, 하이퍼파라미터를 어떻게 선택? -> 100개의 하이퍼파라미터 값으로 100개의 다른 모델을 훈련 시키는 방법이 있음
#
# 위의 방법으로 최적의 하이퍼파라미터를 찾았다고 가정 -> **성능이 예상만큼 좋지않음**
#
# 왜?
#
# *"일반화 오차를 테스트 세트에서 여러번 측정 -> 모델과 하이퍼파라미터가 테스트 세트에 최적화된 모델을 만들었기 때문"*
#
# 해결방법 = **홀드아웃 검증**
# - 훈련 세트의 일부를 떼어내 여러 후보 모델을 평가 후 선택
# - 검증 세트 (개발세트) = 새로운 홀드아웃 세트
#
# ![](https://drive.google.com/uc?id=1ixxE2uiexJvxhXQX9nSnPAfl_zsc720w)
#
#
# 홀드아웃 검증에서
# - 검증 세트가 너무 작으면 모델이 정확하게 평가되지 않음 -> 잘못된 모델 선택으로 이어짐
# - 검증 세트가 너무 크면 남은 훈련 세트가 전체 훈련 세트보다 너무 작아져 이상적이지 않음
#
# 해결방법 : **교차 검증**
# - 작은 검증 세트 여러 개를 사용해 반복적인 교차검증을 수행
# - 검증 세트마다 나머지 데이터에서 훈련한 모델을 해당 검증 세트에 평가
# - 모든 모델의 평가를 평균하면 더 정확한 성능을 측정 가능
# - 단점 : 훈련 시간이 검증 세트의 개수에 비례해 늘어남

# %% [markdown]
# ### 1.6.2 데이터 불일치
#
# 웹에서 다운로드한 사진에 모델을 훈련 후 검증 세트(모바일앱에서 찍은 사진)에서 모델의 성능을 측정했더니 결과가 실망스러움
#
# -> 모델이 훈련 세트에 과대적합되었는지, 웹 사진과 모바일 앱 사진의 데이터가 불일치하기 때문인지 판단 불가
#
# **훈련-개발 세트** : 훈련 세트와 같은 분포에서 뽑았지만 훈련에는 쓰지 않고 평가만 하는 데이터
#
# - 훈련 세트 : 웹 사진 (학습)
# - 훈련-개발 세트 : 웹 사진 (평가만)
# - 검증세트(개발세트) : 모바일 사진 (평가)
# - 테스트 세트 : 모바일 사진 (최종)
#
# 일 때,
# - 훈련세트 성능 좋음 / 훈련-개발 성능 나쁨 : 모델이 훈련 세트에 과대적합됨
# - 훈련-개발 성능 좋음 / 검증 성능 나쁨 : 데이터 불일치

# %% [markdown]
# *공짜 점심 없음 이론 (NFL)*
#
# *: 데이터에 관해 완벽하게 아무런 가정도 하지 않으면 한 모델을 다른 모델보다 선호할 근거가 없음*
#
# *어떤 데이터셋에서는 선형 모델이 가장 잘 들어맞지만 다른 데이터셋에서는 신경망이 잘 들어맞음. 경험하기 전에 더 잘 맞을 거라고 보장할 수 있는 모델이 없기에 모든 모델을 평가해야지 어떤 모델이 최선인지 알 수 있음*
#
# *-> 모든 모델을 평가할 수 없기에 데이터에 관해 타당한 가정을 하고 적절한 모델 몇 가지만 평가하는 거임*
