# %% [markdown]
# <a href="https://colab.research.google.com/github/Le2se0hy/FA_ProAn/blob/main/%ED%95%B8%EC%A6%88%EC%98%A8%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_5%EC%9E%A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 핸즈온 머신러닝_5장 [서포트 벡터 머신]

# %% [markdown]
# **서포트 벡터 머신**은 선형이나 비선형 분류, 회귀, 특이치 탐지에도 사용할 수 있는 다목적 머신러닝 모델임
#
# 중소규모의 비선형 데이터셋, 특히 분류 작업을 잘함 → 매우 큰 데이터셋으로 확장은 X

# %% [markdown]
# ---
# ### 5.1 선형 SVM 분류
